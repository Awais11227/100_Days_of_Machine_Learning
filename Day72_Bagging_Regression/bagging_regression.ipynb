# %% [markdown]
# ## **Bagging Regression**

# %% [markdown]
# ## **Load Dataset**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing()
X, y = data.data, data.target

print("Feature names:", data.feature_names)
print("Shape:", X.shape)
# Out:
# Feature names: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# Shape: (20640, 8)

# %% [markdown]
# ## **Train-Test Split**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=123
)

# %% [markdown]
# ## **Base Models**

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

lr.fit(X_train, y_train)
dt.fit(X_train, y_train)
knn.fit(X_train, y_train)

print("LR R2:", r2_score(y_test, lr.predict(X_test)))
print("DT R2:", r2_score(y_test, dt.predict(X_test)))
print("KNN R2:", r2_score(y_test, knn.predict(X_test)))
# Out:
# LR R2: 0.6104546894797869
# DT R2: 0.6013760891550435
# KNN R2: 0.16261917827057237

# %% [markdown]
# ## **Bagging Regressor**

# %%
from sklearn.ensemble import BaggingRegressor

bag = BaggingRegressor(
    estimator=DecisionTreeRegressor(),  
    n_estimators=50,
    random_state=1
)

bag.fit(X_train, y_train)

print("Train R2:", bag.score(X_train, y_train))
print("Test R2:", bag.score(X_test, y_test))
# Out:
# Train R2: 0.9720657386928859
# Test R2: 0.8103654149510486

# %% [markdown]
# ## **GridSearch**

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'estimator': [None, LinearRegression(), KNeighborsRegressor()],
    'n_estimators': [20, 50],
    'max_samples': [0.5, 1.0],
    'max_features': [0.5, 1.0],
    'bootstrap': [True, False]
}

grid = GridSearchCV(
    BaggingRegressor(random_state=1),
    param_grid=params,
    cv=3,
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train, y_train)

print("Best Params:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Best Params: {'bootstrap': True, 'estimator': None, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# Best Score: 0.7949967658402866

# %% [markdown]
# # Awais Manzoor
