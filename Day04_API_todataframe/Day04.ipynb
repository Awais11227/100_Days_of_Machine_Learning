# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results']).head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     26.8395
# 1  Spanning the years 1945 to 1955, a chronicle o...     28.7729
# 2  In the continuing saga of the Corleone crime f...     15.6745
# 3  The true story of how businessman Oskar Schind...     16.4630
# 4  The defense and the prosecution have rested an...     10.5955
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
# 4  /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10              12 Angry Men
#
#    video  vote_average  vote_count
# 0  False         8.716       29657
# 1  False         8.687       22398
# 2  False         8.571       13550
# 3  False         8.600       17071
# 4  False         8.553        9709

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     26.8395
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     28.7729
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     15.6745
# 3  The true story of how businessman Oskar Schind...   1993-12-15     16.4630
# 4  The defense and the prosecution have rested an...   1957-04-10     10.5955
#
#    vote_average  vote_count
# 0         8.716       29657
# 1         8.687       22398
# 2         8.571       13550
# 3         8.600       17071
# 4         8.553        9709

# %%
df1 = pd.DataFrame()
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df1 = pd.concat([df1, temp_df], ignore_index=True)

# %%
df.to_csv('top_rated_movies.csv', index=False)
