# %% [markdown]
# ## **Import Libraries**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Load dataset**

# %%
df = pd.read_csv("Advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Independent variables or Features
X = df[['TV', 'Radio', 'Newspaper']]
# Dependent or Target variable
y = df.Sales

# %% [markdown]
# ## **Train_test_split**

# %%
from sklearn.model_selection import train_test_split
# Distribute the features(X) and labels(y) into two parts training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=0)

# %%
# Import linear regression model
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
predictions = lin_reg.predict(X_test)
# Print the intercept and coefficients
print("Intercept:",lin_reg.intercept_)
print("Coefficients:",lin_reg.coef_)
# Out:
# Intercept: 2.8925700511511483
# Coefficients: [0.04416235 0.19900368 0.00116268]

# %% [markdown]
# - R-squared MSE MAE RMSE
# - R-squared (R2): R2 = 1 - ( sum( (y - y_pred)^2 ) / sum( (y - y_mean)^2 ) )
# - Mean Squared Error (MSE): MSE = (1/n) * sum( (y - y_pred)^2 )
# - Mean Absolute Error (MAE): MAE = (1/n) * sum( |y - y_pred| )
# - Root Mean Squared Error (RMSE): RMSE = sqrt( (1/n) * sum( (y - y_pred)^2 ) )

# %%
y_test, predictions
# Out:
# (18     11.3
#  170     8.4
#  107     8.7
#  98     25.4
#  177    11.7
#  182     8.7
#  5       7.2
#  146    13.2
#  12      9.2
#  152    16.6
#  61     24.2
#  125    10.6
#  180    10.5
#  154    15.6
#  80     11.8
#  7      13.2
#  33     17.4
#  130     1.6
#  37     14.7
#  74     17.0
#  183    26.2
#  145    10.3
#  45     14.9
#  159    12.9
#  60      8.1
#  123    15.2
#  179    12.6
#  185    22.6
#  122    11.6
#  44      8.5
#  16     12.5
#  55     23.7
#  150    16.1
#  111    21.8
#  22      5.6
#  189     6.7
#  129     9.7
#  4      12.9
#  83     13.6
#  106     7.2
#  134    10.8
#  66      9.5
#  26     15.0
#  113    15.9
#  168    17.1
#  63     14.0
#  8       4.8
#  75      8.7
#  118    15.9
#  143    10.4
#  Name: Sales, dtype: float64,
#  array([10.0494569 ,  7.43052335,  6.97152143, 24.16378667, 12.00215643,
#          6.54334645, 13.09526331, 14.95879164, 11.00528358, 16.27234553,
# ...

# %% [markdown]
# #### **R-squared results**
# - Its value lies between 0 and 1. A value near 0
# represents a poor model while a value near 1 represents a perfect fit.
# -  Sometimes, R-squared results in a negative value. This means your model is worse than the average base model

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Evaluate mean absolute error
print('Mean Absolute Error(MAE):', mean_absolute_error(y_test,predictions))
# Evaluate mean squared error
print("Mean Squared Error(MSE):", mean_squared_error(y_test, predictions))
# Evaluate root mean squared error
print("Root Mean Squared Error(RMSE):", np.sqrt(mean_squared_error(y_test,
predictions)))
# Evaluate R-square
print("R-Square:",r2_score(y_test, predictions))
# Out:
# Mean Absolute Error(MAE): 1.3000320919235455
# Mean Squared Error(MSE): 4.0124975229171005
# Root Mean Squared Error(RMSE): 2.003121944095541
# R-Square: 0.8576396745320893

# %% [markdown]
# ### **interpretation**
# interpretation Metric Meaning Good Value MAE Avg. absolute error Lower MSE Avg. squared error Lower RMSE Square root of MSE
# Lower R² % variance explained Closer to 1
